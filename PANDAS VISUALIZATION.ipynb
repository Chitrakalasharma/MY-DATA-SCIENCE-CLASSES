# %% [markdown]
# pandas visualization

# %%
#barplot
import pandas as pd
import numpy as np 

df =pd.DataFrame(np.random.rand(10,4),columns=['a','b' ,'c','d'])
print(df)
df.plot.bar()
# Out:
#           a         b         c         d
# 0  0.435368  0.299112  0.221126  0.213453
# 1  0.994143  0.952141  0.238943  0.040837
# 2  0.578706  0.588497  0.652072  0.348598
# 3  0.111815  0.288722  0.652156  0.560112
# 4  0.679928  0.440865  0.310501  0.096315
# 5  0.737548  0.655224  0.752768  0.475946
# 6  0.122102  0.320431  0.357607  0.852422
# 7  0.534934  0.474720  0.222943  0.779153
# 8  0.608305  0.044276  0.917054  0.472650
# 9  0.221864  0.505415  0.377823  0.642176
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df=pd.DataFrame(np.random.rand(10,5),columns=['A' ,'B','C','D','E'])
print(df)
df.plot.box()
# Out:
#           A         B         C         D         E
# 0  0.823203  0.590862  0.713917  0.595740  0.624752
# 1  0.963213  0.953526  0.205081  0.715348  0.751287
# 2  0.158602  0.501227  0.125029  0.520087  0.067836
# 3  0.105770  0.963735  0.666770  0.685026  0.735612
# 4  0.189636  0.939856  0.646160  0.348043  0.219530
# 5  0.674367  0.187503  0.804535  0.976875  0.118113
# 6  0.003915  0.744749  0.271943  0.685910  0.746750
# 7  0.856696  0.101027  0.098740  0.193508  0.028086
# 8  0.309443  0.129534  0.630946  0.268866  0.660869
# 9  0.655646  0.211091  0.266657  0.289156  0.287724
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])
df.plot.scatter(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
